# %%
import numpy as np
a = np.array([1, 1, 4, 4])
b = np.array([1, 1, 5, 5])
range = np.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2 + \
                 (a[2] - b[2])**2 + (a[3] - b[3])**2)
range
# Out:
# 1.4142135623730951

# %%
np.sum(b)/ b.size
# Out:
# 3.0

# %%
np.sum(a)/ a.size
# Out:
# 2.5

# %%
a = a * (np.sum(b)/ b.size) / (np.sum(a)/ a.size)

# %%
np.sum(a)/ a.size
# Out:
# 3.0

# %%
range = np.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2 + \
                 (a[2] - b[2])**2 + (a[3] - b[3])**2)
range
# Out:
# 0.40000000000000013

# %%
a
# Out:
# array([1.2, 1.2, 4.8, 4.8])
