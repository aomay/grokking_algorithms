# %%
import numpy as np

# %%
def binary_search(lst, num):
    start = 0
    stop = len(lst1)
    mid = int(np.floor(((start + stop) / 2)))
    while lst[mid] != num:
        mid = int(np.floor(((start + stop) / 2)))
        print(start, stop, mid)
        if lst[mid] > num:
            stop = mid
        elif lst[mid] < num:
            start = mid
    return mid

# %%
lst1 = [2, 3, 4, 5, 9, 10, 15, 22, 100, 110]
num = 110
binary_search(lst1, num)
# Out:
# 0 10 5
# 5 10 7
# 7 10 8
# 8 10 9
# 9
